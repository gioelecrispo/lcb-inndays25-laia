# %% [markdown]
# # Evaluating Search Relevance with Azure Al Search
# Source: [step by step guide to measuring azure ai search relevance](https://farzzy.hashnode.dev/step-by-step-guide-to-measuring-azure-ai-search-relevance-the-hello-world-of-information-retrieval)

# %%
# requirements for running the evaluations
# httpx==0.27.2 is needed to avoid an inconsistencies in the openai interface
# %pip install azure-identity==1.23.0 azure-search-documents==11.5.2 openai==1.43.1 ranx==0.3.20 dotenv tenacity pandas httpx==0.27.2 voyageai==0.2.4
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity==1.23.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (1.23.0)
# Requirement already satisfied: azure-search-documents==11.5.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (11.5.2)
# Requirement already satisfied: openai==1.43.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (1.43.1)
# Requirement already satisfied: ranx==0.3.20 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (0.3.20)
# Requirement already satisfied: dotenv in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (0.9.9)
# Requirement already satisfied: tenacity in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (9.1.2)
# Requirement already satisfied: pandas in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: httpx==0.27.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (0.27.2)
# Requirement already satisfied: voyageai==0.2.4 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (0.2.4)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-identity==1.23.0) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-identity==1.23.0) (45.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-identity==1.23.0) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-identity==1.23.0) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-identity==1.23.0) (4.13.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-search-documents==11.5.2) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-search-documents==11.5.2) (0.7.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (2.11.5)
# Requirement already satisfied: sniffio in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from openai==1.43.1) (4.67.1)
# Requirement already satisfied: certifi in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from httpx==0.27.2) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from httpx==0.27.2) (1.0.9)
# Requirement already satisfied: idna in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from httpx==0.27.2) (3.10)
# Requirement already satisfied: numpy in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (2.2.6)
# Requirement already satisfied: numba>=0.54.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (0.61.2)
# Requirement already satisfied: tabulate in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (0.9.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (1.15.3)
# Requirement already satisfied: ir-datasets in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (0.5.10)
# Requirement already satisfied: rich in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (14.0.0)
# Requirement already satisfied: orjson in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (3.10.18)
# Requirement already satisfied: lz4 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (4.4.4)
# Requirement already satisfied: cbor2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (5.6.5)
# Requirement already satisfied: seaborn in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (0.13.2)
# Requirement already satisfied: fastparquet in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ranx==0.3.20) (2024.11.0)
# Requirement already satisfied: aiohttp<4.0,>=3.5 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from voyageai==0.2.4) (3.11.18)
# Requirement already satisfied: aiolimiter<2.0.0,>=1.1.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from voyageai==0.2.4) (1.2.1)
# Requirement already satisfied: requests<3.0,>=2.20 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from voyageai==0.2.4) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from aiohttp<4.0,>=3.5->voyageai==0.2.4) (1.20.0)
# Requirement already satisfied: h11>=0.16 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from httpcore==1.*->httpx==0.27.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.43.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.43.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.43.1) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from requests<3.0,>=2.20->voyageai==0.2.4) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from requests<3.0,>=2.20->voyageai==0.2.4) (2.4.0)
# Requirement already satisfied: python-dotenv in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from dotenv) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from azure-core>=1.31.0->azure-identity==1.23.0) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from cryptography>=2.5->azure-identity==1.23.0) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity==1.23.0) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity==1.23.0) (2.10.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from numba>=0.54.1->ranx==0.3.20) (0.44.0)
# Requirement already satisfied: colorama in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from tqdm>4->openai==1.43.1) (0.4.6)
# Requirement already satisfied: cramjam>=2.3 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from fastparquet->ranx==0.3.20) (2.10.0)
# Requirement already satisfied: fsspec in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from fastparquet->ranx==0.3.20) (2025.3.0)
# Requirement already satisfied: packaging in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from fastparquet->ranx==0.3.20) (25.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (4.13.4)
# Requirement already satisfied: inscriptis>=2.2.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (5.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (6.0.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (3.4.0)
# Requirement already satisfied: unlzw3>=0.2.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from ir-datasets->ranx==0.3.20) (20.0.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets->ranx==0.3.20) (2.7)
# Requirement already satisfied: cbor>=1.0.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from trec-car-tools>=2.5.4->ir-datasets->ranx==0.3.20) (1.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from rich->ranx==0.3.20) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from rich->ranx==0.3.20) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->ranx==0.3.20) (0.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from seaborn->ranx==0.3.20) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\crispogioele\desktop\lcb-innovation-days\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx==0.3.20) (3.2.3)

# %% [markdown]
# # Step 1: Environment and Resources configuration
#
# This step is composed of many substep:
#
# 1. Load environment variables
#
# 2. Open Al embeddings configuration
#
# 3. Azure Al Search confguration
#
# 4. Load data and configure dataset

# %% [markdown]
# ## Step 1.1: Load environment variables

# %%
import os

from dotenv import load_dotenv

load_dotenv() # take environment variables from .env file
load_dotenv('.env.iva') # take environment variables from .env.iva file
# Out:
# True

# %% [markdown]
# ## Step 1.2: Open Al embeddings configuration

# %%
from abc import ABC, abstractmethod  
from typing import List   
  
class BaseEmbeddingsClient(ABC):  
    """  
    Abstract base class for an Embeddings Client.  
    Child classes must implement the generate_embeddings method.  
    """  
  
    def __init__(self, embeddings_config):  
        self.embeddings_config = embeddings_config  
        self.model = self.initialize_model()  
  
    @abstractmethod  
    def initialize_model(self):  
        """  
        Abstract method to initialize and return the model instance.  
        Needs to be implemented by child classes.  
        """  
        pass  
    
    @abstractmethod 
    async def generate_embeddings(self, model_inputs: List[str]):  
        """  
        Abstract method to generate embeddings.   
        Needs to be implemented by child classes.  
        """  
        raise NotImplementedError("This method should be implemented by subclasses.")
        

    async def generate_embeddings_batches(self, model_inputs: List[str], batch_size: int = 20):  
        """  
        Abstract method to generate embeddings.   
        Needs to be implemented by child classes.  
        """  
        responses = []
        # Generate embeddings in batches
        batch_count = 0
        for i in range(0, len(model_inputs), batch_size):
            j = i + batch_size if i + batch_size <= len(model_inputs) else len(model_inputs)
            batch = model_inputs[i:j]
            print(f"[Embeddings] [{self.embeddings_config['name']}] Processing batch #{batch_count}, Batch: {1} -> {j}")
            try:
                batch_response = await self.generate_embeddings(
                    model_inputs=batch,
                )
                responses.extend(batch_response)
                batch_count += 1

            except Exception as e:
                print(f"[Embeddings][{self.embeddings_config['name']}] Error while computing embeddings: {e}. Retrying...")
                raise

        return responses

# %%
# Initialize OpenAI client
import voyageai
from openai import AsyncAzureOpenAI
from typing import List
from tenacity import retry, stop_after_attempt, wait_fixed



#async_credential = AsyncDefaultAzureCredential()
openai_api_key = os.getenv("AZURE_OPENAI_EMBEDDINGS_SERVICE_KEY")
voyage_api_key = os.getenv("VOYAGE_API_KEY")

openai_embeddings_ada2_config = {
    "name": "ada2",
    "service_name": os.getenv("AZURE_OPENAI_EMBEDDINGS_SERVICE_NAME"),
    "api_version": os.getenv("AZURE_OPENAI_EMBEDDINGS_ADA2_API_VERSION"),
    "deployment_model": os.getenv("AZURE_OPENAI_EMBEDDINGS_ADA2_DEPLOYMENT_MODEL"),
    "vector_dimensions": 1536
}

openai_embeddings_t3small_config = {
    "name": "t3small",
    "service_name": os.getenv("AZURE_OPENAI_EMBEDDINGS_SERVICE_NAME"), 
    "api_version": os.getenv("AZURE_OPENAI_EMBEDDINGS_T3SMALL_API_VERSION"),
    "deployment_model": os.getenv("AZURE_OPENAI_EMBEDDINGS_T3SMALL_DEPLOYMENT_MODEL"),
    "vector_dimensions": 1536
}

voyage_embeddings_law2_config = {
    "name": "voyage-law-2",
    "input_type": "document",
    "vector_dimensions": 1024
}

class AzureEmbeddingsClient(BaseEmbeddingsClient):

    def initialize_model(self):  
        """  
        Initialize and return the Azure-specific AsyncAzureOpenAI model.  
        """  
        return AsyncAzureOpenAI(  
            api_version=self.embeddings_config["api_version"],
            api_key=openai_api_key,
            azure_endpoint=f'https://{self.embeddings_config["service_name"]}.openai.azure.com',  
            max_retries=2,  
        ) 
    
    @retry(
        stop_after_attempt(15), #Retry up to X times
        wait_fixed(10), # Wait X seconds between retries
    )
    async def generate_embeddings(self, model_inputs: List[str]):
        response = await self.model.embeddings.create(
            model=self.embeddings_config["deployment_model"], 
            input=model_inputs,
        )
        return [i.embedding for i in response.data]

class VoyageEmbeddingsClient(BaseEmbeddingsClient):
    def initialize_model(self):  
        """  
        Initialize and return the SyncVoyage model.  
        """  
        return voyageai.Client()
    
    @retry(
        stop_after_attempt(15), #Retry up to X times
        wait_fixed(10), # Wait X seconds between retries
    )
    async def generate_embeddings(self, model_inputs: List[str]):
        return self.model.embed(model_inputs, model=self.embeddings_config["name"], input_type=self.embeddings_config["input_type"]).embeddings
    
class EmbeddingClientFactory:
    
    @staticmethod
    def create(embeddings_config) -> BaseEmbeddingsClient:
        if "input_type" in embeddings_config:
            embeddings_client = VoyageEmbeddingsClient(embeddings_config)
        else:
            embeddings_client = AzureEmbeddingsClient(embeddings_config)
        return embeddings_client

# %% [markdown]
# ## Step 1.3: Azure Al Search configuration

# %%
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient

sync_credential = AzureKeyCredential(os.getenv("SEARCH_SERVICE_KEY"))

azure_search_config = {
    "service_name": os.getenv("SEARCH_SERVICE_NAME"),
    "index_name": os.getenv("SEARCH_INDEX_NAME"),
    "api_version": os.getenv("SEARCH_API_VERSION"),
    "service_endpoint": f'https://{os.getenv("SEARCH_SERVICE_NAME")}.search.windows.net'
}

# %% [markdown]
# ## Step 1.4: Load data and configure dataset

# %%
import pandas as pd

docs_number = 100000000 # 3200

# Load dataset queries and groundtruth
folder = "legal-docs"
documents_df = pd.read_csv(f"dataset/{folder}/document.csv", sep="\t", index_col="id", keep_default_na=False)
queries_df = pd.read_csv(f"dataset/{folder}/query.csv", sep="\t", index_col="query_id")
labels_df = pd.read_csv(f"dataset/{folder}/label.csv", sep="\t")

# Map ground truth labels to scores
relevancy_scores = {"Relevant": 10, "Irrelevant": 0}
labels_df["score"] = labels_df["label"].map(relevancy_scores)

# Ensure query id and doc_id columns are of type string (object)
labels_df["query_id"] = labels_df["query_id"].astype(str)
labels_df["doc_id"] = labels_df["doc_id"].astype(str)

# Filter by the document number
contents = documents_df["content"].tolist()[:docs_number]
filtered_documents_df = documents_df[:docs_number]
filtered_labels_df = labels_df.loc[labels_df['doc_id'].isin(filtered_documents_df['doc_id'])]
filtered_queries_df = queries_df[queries_df.index.isin(filtered_labels_df['query_id'].astype(int))]

print(f"Number of documents: {len(filtered_documents_df)}")
print(f"Number of queries: {len(filtered_queries_df)}")
print(f"Number of labels: {len(filtered_labels_df)}")
# Out:
# Number of documents: 6516
# Number of queries: 2578
# Number of labels: 17046

# %%
filtered_documents_df.head()
# Out:
#               chunk_id                                            content  \
# id
# eurlex_0__0          0  Name: Decision (EU) 2019/276 of the European P...
# eurlex_0__1          1  (6) In order to allow for the quick use of the...
# eurlex_10__0         0  Name: Decision (EU) 2018/515 of the European P...
# eurlex_10__1         1  For the general budget of the Union for the fi...
# eurlex_11__0         0  Name: Decision (EU) 2018/508 of the European P...
#
#                  doc_id category
# id
# eurlex_0__0    eurlex_0   eurlex
# eurlex_0__1    eurlex_0   eurlex
# eurlex_10__0  eurlex_10   eurlex
# eurlex_10__1  eurlex_10   eurlex
# eurlex_11__0  eurlex_11   eurlex

# %%
filtered_queries_df.head()
# Out:
#                                                       query
# query_id
# 0         what is the purpose of the european parliament...
# 1                   what is the daily rate for a consultant
# 2                     when does per unit retains reclassify
# 3         when does the decision to use the flexibility ...
# 4                    what is required to receive cops award

# %%
filtered_labels_df.head()
# Out:
#   query_id           id    doc_id  chunk_id       label  score
# 0        0  eurlex_0__0  eurlex_0         0    Relevant     10
# 1        1  eurlex_0__0  eurlex_0         0  Irrelevant      0
# 2        2  eurlex_0__0  eurlex_0         0  Irrelevant      0
# 3        3  eurlex_0__1  eurlex_0         1    Relevant     10
# 4        4  eurlex_0__1  eurlex_0         1  Irrelevant      0

# %% [markdown]
# # Step 2: Prepare the code to run the evaluation
#
# This is composed of many substeps:
#
# 1. Generate embeddings
#
# 2. Create/update a search index and upload data
#
# 3. Set-up code for searching
#
# 4. Gather search data (score)
#
# 5. Set-up evaluation tool (ranx)

# %% [markdown]
# ## Step 2.1: Generate embeddings

# %%
async def generate_embeddings(embeddings_client, contents):
    content_embeddings = await embeddings_client.generate_embeddings_batches(contents)
    return content_embeddings

# %% [markdown]
# ## Step 2.2: Create/update a search index and upload data

# %%
from azure.search.documents.indexes.models import (
    HnswAlgorithmConfiguration,
    HnswParameters,
    SearchField,
    SearchFieldDataType,
    SearchIndex,
    SimpleField,
    VectorSearch,
    VectorSearchAlgorithmKind,
    VectorSearchAlgorithmMetric,
    VectorSearchProfile
)

def create_or_update_index(
    azure_search_config, index_name, vector_field_type, vector_dimensions
):
    search_index_client = SearchIndexClient(endpoint=azure_search_config["service_endpoint"], credential=sync_credential)
    # Define the search index fields based on your product schema
    fields = [
        SimpleField(name="id", type=SearchFieldDataType.String, key=True), 
        SimpleField(name="doc_id", type=SearchFieldDataType.String, searchable=True, filterable=True),
        SearchField(name="category", type=SearchFieldDataType.String, searchable=True, filterable=True),
        SearchField(name="content", type=SearchFieldDataType.String, searchable=True),
        SearchField(name="content_vector", type=vector_field_type, vector_search_dimensions=vector_dimensions, vector_search_profile_name="my-vector-config"),
    ]
    
    # Vector search configuration with HNSW algorithm and query vectorizer
    vector_search = VectorSearch(
        profiles=[
            VectorSearchProfile( 
                name="my-vector-config", 
                algorithm_configuration_name="my-hnsw", 
            )
        ],
        algorithms=[
            HnswAlgorithmConfiguration(
                name="my-hnsw", 
                kind=VectorSearchAlgorithmKind.HNSW, 
                parameters=HnswParameters(metric=VectorSearchAlgorithmMetric.COSINE),
            )
        ]
    )

    index= SearchIndex(name=index_name, fields=fields, vector_search=vector_search)
    search_index_client.create_or_update_index(index=index)
    print(f"[SearchIndexClient][{index_name}] Created or updated index.")

# %%
from azure.search.documents import SearchIndexingBufferedSender

def upload_embeddings_to_index(service_endpoint, index_name, documents_df, content_embeddings, batch_size=100): 
    documents = []
    # Prepare documents with embeddings
    for i, content_embedding in enumerate(content_embeddings):
        document = {
            "id": str(documents_df.index[i]),
            "doc_id": str(documents_df.iloc[i]["doc_id"]),
            "category": documents_df.iloc[i]["category"],
            "content": documents_df.iloc[i]["content"], 
            "content_vector": content_embedding,
        } 
        documents.append(document)

        # Initialize SearchIndexingBufferedSender for batch uploads 
    with SearchIndexingBufferedSender(
        endpoint=service_endpoint,
        index_name=index_name,
        credential=sync_credential,
        auto_flush_interval=60,  # Automatically flush every 60 seconds
        initial_batch_action_count=batch_size # Batch size for actions
    ) as batch_client:
        # Upload documents in batches
        for doc_batch in [documents[i:i + batch_size] for i in range(0, len(documents), batch_size)]:
            batch_client.upload_documents(documents=doc_batch)

        print(f"[SearchIndexClient][{index_name}] Uploaded {len(documents)} documents using buffered sender.")

    #Ensure all documents are flushed
    batch_client.flush()

# %% [markdown]
# ## Step 2.3: Set-up code for searching

# %%
async def search(search_client, query_embeddings, vector_fields: str, top: int): 

    vector_query = {
        "kind": "vector", 
        "vector": query_embeddings, 
        "fields": vector_fields,
        "k": top, 
    }
    response = search_client.search(search_text=None, vector_queries=[vector_query], top=top)

    return response

# %% [markdown]
# ## Step 2.4: Gather search data (score)

# %%
from collections import defaultdict

async def gather_search_data(search_client, embeddings_queries, field, top): 
    run_dict = defaultdict(dict)

    for index, query in embeddings_queries.items():
        query_text = query["text"]
        query_embeddings = query["embeddings"]
        #print(f"[SearchClient][{search_client._index_name}] Searching query {index}. Query: {query_text}")

        # Perform vector search using the Azure AI Search client
        results = await search(search_client, query_embeddings, vector_fields=field, top=top)
        

        query_id = f"{index}"  # Ensure query id matches what's in qrels
        # Use the actual product id from the search results instead of generating a 'doc 
        for i, result in enumerate(results): 
            #print(f"[SearchClient][{search_client._index_name}] - Searching query {index}. Result {i}: {result}")
            doc_id = result['doc_id'] 
            score = result['@search.score']

            # Populate the run dict using product id and score
            run_dict[str(query_id)][str(doc_id)] = score
        
        print(f"[SearchClient][{search_client._index_name}] run_dict[{query_id}]: {run_dict[query_id]} -  Query: {query_text}")
    
    return run_dict

# %% [markdown]
# ## Step 3: Execute the evaluation process

# %%
async def populate_index(azure_search_config, embeddings_config, documents_df, data):
    # create search index
    index_name = f'{azure_search_config["index_name"]}-{embeddings_config["name"]}'

    create_or_update_index(
        azure_search_config,
        index_name=index_name,
        vector_field_type="Collection(Edm.Single)",  # OpenAI embedding storage format dim: 1536
        vector_dimensions=embeddings_config["vector_dimensions"]
    )
    
    # Generate the embeddings
    embeddings_client = EmbeddingClientFactory.create(embeddings_config)
 
    content_embeddings = await generate_embeddings(
        embeddings_client,
        data["contents"]
    )

    # Upload embeddings to respective indexes
    upload_embeddings_to_index(
        azure_search_config["service_endpoint"],
        index_name,
        documents_df,
        content_embeddings
    )

async def get_queries_embeddings(embeddings_config, queries_df):
    """ 
    Generate embeddings for the queries in the dataset.
    Returns a dictionary with query ids as keys and their embeddings and text as values.
    """
    embeddings_client = EmbeddingClientFactory.create(embeddings_config)
    
    queries_embeddings = await embeddings_client.generate_embeddings_batches(
        model_inputs=queries_df["query"].tolist()
    )
    
    return {
        str(index): {"text": query, "embeddings": embedding} 
        for index, (query, embedding) in enumerate(zip(queries_df["query"].tolist(), queries_embeddings))
    }

async def evaluation_process(azure_search_config, embeddings_queries, model_name, k=3):
    # create search index
    index_name = f'{azure_search_config["index_name"]}-{model_name}'
    # Perform search
    search_client = SearchClient(
        endpoint=azure_search_config["service_endpoint"],
        index_name=index_name,
        credential=sync_credential, 
        api_version=azure_search_config["api_version"]
    )
    

    content_run_dict = await gather_search_data(search_client, embeddings_queries, "content_vector", top=k)
    
    return content_run_dict

# %% [markdown]
# # Step 4: Compare the results

# %%
from ranx import compare


def compare_runs(qrels, *runs, result_folder, k=3):
    # Compare search relevance metrics across different models
    
    report = compare(
        qrels=qrels,
        runs=[
            *runs
        ],
        metrics=[
            f"precision@{k}", 
            f"recall@{k}", 
            f"mrr@{k}", 
            f"dcg@{k}", 
            f"ndcg@{k}"
        ],
        make_comparable=True # Ensure that qrels and runs have matching query IDs
    )

    # Convert the report to a DataFrame and display it
    results_df = report.to_dataframe()

    # Optionally, export results to a CSV
    results_df.to_csv(f"results/{result_folder}/comparison_results_k{k}.csv", index=False)
    return results_df

# %%
data = {
    "contents": contents
}
await populate_index(azure_search_config, openai_embeddings_ada2_config, filtered_documents_df, data)
await populate_index(azure_search_config, openai_embeddings_t3small_config, filtered_documents_df, data)
await populate_index(azure_search_config, voyage_embeddings_law2_config, filtered_documents_df, data)

# %%
import json 
query_embeddings_folder = "resources/data/embeddings"
os.makedirs(query_embeddings_folder, exist_ok=True)

queries_embeddings_ada2 = await get_queries_embeddings(openai_embeddings_ada2_config, filtered_queries_df)
with open(f"{query_embeddings_folder}/queries_embeddings_ada2.json", "w") as file:
    json.dump(queries_embeddings_ada2, file, indent=2)
    
queries_embeddings_t3small = await get_queries_embeddings(openai_embeddings_t3small_config, filtered_queries_df)
with open(f"{query_embeddings_folder}/queries_embeddings_t3small.json", "w") as file:
    json.dump(queries_embeddings_t3small, file, indent=2)
    
queries_embeddings_voyage_law2 = await get_queries_embeddings(voyage_embeddings_law2_config, filtered_queries_df)
with open(f"{query_embeddings_folder}/queries_embeddings_voyage_law2.json", "w") as file:
    json.dump(queries_embeddings_voyage_law2, file, indent=2)

# %%
# Read saved embeddings
import json

query_embeddings_folder = "resources/data/embeddings"
with open(f"{query_embeddings_folder}/queries_embeddings_ada2.json", "r") as file:
    queries_embeddings_ada2 = json.load(file)
with open(f"{query_embeddings_folder}/queries_embeddings_t3small.json", "r") as file:
    queries_embeddings_t3small = json.load(file)
with open(f"{query_embeddings_folder}/queries_embeddings_voyage_law2.json", "r") as file:
    queries_embeddings_voyage_law2 = json.load(file)

# %%
results_dfs = {}
compare_dfs = {}

# %%
k_list = [5, 10]


for k in k_list:    # k being the number of top results to retrieve
    ada2_results = await evaluation_process(azure_search_config, queries_embeddings_ada2, k=k, model_name=openai_embeddings_ada2_config["name"])
    t3small_results = await evaluation_process(azure_search_config, queries_embeddings_t3small, k=k, model_name=openai_embeddings_t3small_config["name"])
    voyage_law2_results = await evaluation_process(azure_search_config, queries_embeddings_voyage_law2, k=k, model_name=voyage_embeddings_law2_config["name"])
    
    results_dfs[k] = {
        "ada2": ada2_results,
        "t3small": t3small_results,
        "voyage_law2": voyage_law2_results
    }
# Out:
# [SearchClient][ranx-index-voyage-law-2] run_dict[1065]: {'guidance_14': 0.664356, 'guidance_91': 0.65949273, 'guidance_92': 0.65026057, 'guidance_76': 0.6536264, 'guidance_69': 0.6432963, 'guidance_93': 0.6385716} -  Query: cops pass program -
# [SearchClient][ranx-index-voyage-law-2] run_dict[
-
# [SearchClient][ranx-index-voyage-law-2] run_dict[1125]: {'legal-advice_83': 0.57992715, 'legal-advice_0': 0.59153646, 'legal-advice_19': 0.58573604, 'memos_39': 0.5805814, 'guidance_69': 0.5797649, 'memos_87': 0.5774681, 'memos_36': 0.57684124} -  Query: what is the authority upon which a position may be reasonably based? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1126]: {'guidance_92': 0.6666806, 'guidance_93': 0.6648228, 'guidance_91': 0.6594588, 'guidance_73': 0.65689445, 'guidance_75': 0.6544745, 'guidance_76': 0.64680254, 'guidance_74': 0.6438581, 'guidance_54': 0.6423444, 'guidance_40': 0.6415278} -  Query: when will award funds be released to the community -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1127]: {'guidance_34': 0.63504815, 'guidance_61': 0.6310753} -  Query: what is the role of the federal female offender branch? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1128]: {'guidance_27': 0.6746932, 'guidance_99': 0.6685359, 'guidance_57': 0.6482418, 'guidance_32': 0.65387344, 'guidance_61': 0.6537719, 'guidance_52': 0.64950705, 'guidance_36': 0.6490704, 'guidance_42': 0.6487284} -  Query: opi number for federal bureau of prisons -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1129]: {'guidance_59': 0.63625354, 'guidance_17': 0.63195324, 'guidance_56': 0.6424332, 'guidance_65': 0.6298729} -  Query: what is the level progress for inmate -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1130]: {'memos_76': 0.735085, 'memos_66': 0.6274348, 'memos_51': 0.6397676, 'memos_79': 0.63970727, 'memos_18': 0.627177, 'memos_60': 0.62631184} -  Query: congressional request for appointment calendars of a former gsa official -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1131]: {'guidance_52': 0.6420449, 'guidance_57': 0.6421081, 'guidance_48': 0.6420984, 'guidance_45': 0.64121336} -  Query: do inmates need to be notified -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1132]: {'guidance_30': 0.72385126, 'guidance_14': 0.72385126, 'guidance_15': 0.7122744, 'guidance_12': 0.7122744, 'guidance_29': 0.72385126, 'guidance_38': 0.7173297, 'guidance_36': 0.7159422, 'guidance_39': 0.71442586} -  Query: when is doj sponsored conference report form released -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1133]: {'guidance_91': 0.6934519, 'guidance_92': 0.5975118, 'guidance_76': 0.64587104, 'guidance_73': 0.6128909, 'guidance_42': 0.59741294, 'guidance_53': 0.6014795, 'guidance_24': 0.59732985} -  Query: is an award conditional or unenforceable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1134]: {'guidance_91': 0.65752137, 'guidance_38': 0.63925064, 'guidance_92': 0.6471871, 'guidance_14': 0.6373382, 'guidance_29': 0.6388479} -  Query: what is the award condition on a pass report -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1135]: {'guidance_69': 0.63689077, 'guidance_92': 0.5871546, 'guidance_91': 0.5876074, 'legal-advice_0': 0.58332616} -  Query: are internet references considered endorsement -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1136]: {'guidance_49': 0.67880774, 'guidance_67': 0.6842128} -  Query: who must register as a sex offender -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1137]: {'legal-advice_30': 0.61086124, 'legal-advice_40': 0.6109791, 'legal-advice_99': 0.6088796} -  Query: which circuit upheld the regulation for interest due under the notes payable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1138]: {'guidance_30': 0.7153324, 'guidance_12': 0.71300536, 'guidance_14': 0.68035483, 'guidance_92': 0.6782035, 'guidance_25': 0.6628955, 'guidance_22': 0.66286415, 'guidance_40': 0.65614516, 'guidance_36': 0.653464, 'guidance_38': 0.6530239, 'guidance_53': 0.6512058} -  Query: where is the cops office website -
# [SearchClient][ranx-index-voyage-law-2] run_dict[
-
# [SearchClient][ranx-index-voyage-law-2] run_dict[1202]: {'guidance_38': 0.64924634, 'guidance_54': 0.64057654, 'guidance_30': 0.6398461, 'guidance_12': 0.6398389, 'guidance_36': 0.6383696, 'guidance_8': 0.63830554, 'guidance_39': 0.6373995, 'guidance_23': 0.63211125, 'guidance_29': 0.6293511} -  Query: what is a state information technology point of contact -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1203]: {'guidance_93': 0.6344112, 'guidance_40': 0.6447297, 'guidance_74': 0.63286203, 'guidance_51': 0.6357148, 'guidance_54': 0.6351648, 'guidance_92': 0.63462675, 'guidance_55': 0.6338815} -  Query: when is the deadline for sf 425 -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1204]: {'legal-advice_75': 0.605349, 'legal-advice_40': 0.6104661, 'legal-advice_18': 0.60660565} -  Query: what type of transaction is domestic subsidiary in michigan -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1205]: {'memos_2': 0.60883015, 'memos_74': 0.61301816} -  Query: why did rockefeller donate to vice president -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1206]: {'guidance_38': 0.64372545, 'guidance_36': 0.6427727, 'guidance_74': 0.63602585, 'guidance_39': 0.6348978, 'guidance_30': 0.6343646, 'guidance_73': 0.6337903, 'guidance_12': 0.6334671, 'guidance_24': 0.632162, 'guidance_53': 0.63240415} -  Query: what is the conflict of interest condition -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1207]: {'memos_91': 0.65441436, 'guidance_91': 0.63315654, 'guidance_28': 0.6327734, 'guidance_29': 0.632081, 'memos_49': 0.631409, 'guidance_12': 0.63127124, 'guidance_22': 0.6302074, 'guidance_14': 0.6300826, 'guidance_24': 0.6290801, 'guidance_13': 0.6283099} -  Query: what is the condition of the consolidated appropriations act? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1208]: {'legal-advice_79': 0.60496795, 'legal-advice_77': 0.62752706, 'legal-advice_43': 0.6142749, 'legal-advice_94': 0.60686904, 'legal-advice_45': 0.6065922} -  Query: who argued that the intangibles were not exchanged -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1209]: {'guidance_40': 0.64065003, 'guidance_55': 0.6409207, 'guidance_30': 0.64643145, 'guidance_12': 0.641734, 'guidance_93': 0.64114785} -  Query: what is chp award number -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1210]: {'guidance_45': 0.64736557, 'legal-advice_0': 0.65320206, 'guidance_74': 0.64632213} -  Query: do auditors have to disclose their conduct -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1211]: {'guidance_57': 0.6661751, 'guidance_20': 0.68022984, 'guidance_61': 0.6751605} -  Query: who supervise federal inmates released on parole -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1212]: {'guidance_91': 0.57805234, 'guidance_76': 0.5890668, 'guidance_42': 0.5883448, 'guidance_92': 0.5881288, 'memos_96': 0.576693, 'memos_39': 0.57667273, 'memos_1': 0.5754805, 'memos_56': 0.572503, 'guidance_30': 0.57223684} -  Query: are unenforceability conditions deemed severable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1213]: {'guidance_41': 0.6299689, 'guidance_91': 0.6341241, 'guidance_13': 0.62606084, 'guidance_28': 0.6271691} -  Query: can you use the camp award to benefit the recipient -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1214]: {'guidance_29': 0.6695607, 'guidance_30': 0.66942495, 'guidance_12': 0.66941714, 'guidance_24': 0.65561044, 'guidance_13': 0.6605487, 'guidance_39': 0.65970904, 'guidance_38': 0.6525349, 'guidance_15': 0.6555349} -  Query: who sign a usdoj award -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1215]: {'memos_95': 0.65726787} -  Query: are nontransformative uses unlikely to be regarded as fair ones -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1216]: {'guidance_70': 0.60155964, 'guidance_65': 0.6015724, 'guidance_58': 0.6116785} -  Query: what is the role of a precertification evaluation in a mental health case -
# [SearchClient][ranx-index-voyage-law-2] run_dict[
-
# [SearchClient][ranx-index-voyage-law-2] run_dict[1229]: {'guidance_91': 0.65157104, 'guidance_73': 0.65415746, 'guidance_53': 0.6519788, 'guidance_24': 0.6517504} -  Query: what is the tribal access program -
# [SearchClient][ranx-index-voyage-law-2] run_dict[1230]: {'guidance_36': 0.7454957, 'guidance_39': 0.74510074, 'guidance_76': 0.74494827, 'guidance_38': 0.7429513, 'guidance_42': 0.74062157, 'guidance_92': 0.740305, 'guidance_8': 0.7388097, 'guidance_14': 0.7387692, 'guidance_29': 0.7379504, 'guidance_12': 0.73682445} -  Query: when do you report compensation for subrecipient executive -
# ...
# [SearchClient][ranx-index-voyage-law-2] run_dict[2517]: {'memos_78': 0.64723957, 'memos_57': 0.5988962, 'memos_10': 0.5980846, 'memos_85': 0.59733176} -  Query: what is the law regarding iraq communications between retired navy flag officer and marine corps commander -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2518]: {'legal-advice_0': 0.62206227, 'guidance_99': 0.6193598, 'guidance_93': 0.63222283, 'guidance_75': 0.6216539, 'guidance_65': 0.6178454} -  Query: requirements for continuing education programs -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2519]: {'guidance_65': 0.6249126, 'guidance_30': 0.6387991, 'guidance_12': 0.6361423, 'guidance_14': 0.6323453, 'guidance_92': 0.62330914, 'guidance_74': 0.62290555} -  Query: how to earn a program achievement award -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2520]: {'legal-advice_50': 0.6374017, 'legal-advice_79': 0.62313765, 'legal-advice_1': 0.6203539, 'legal-advice_45': 0.6270018, 'legal-advice_9': 0.6249707, 'legal-advice_16': 0.61756665} -  Query: what is the amortize period for section 197 -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2521]: {'guidance_91': 0.73383147, 'guidance_51': 0.7315934, 'guidance_42': 0.7311587, 'guidance_39': 0.72970164, 'guidance_76': 0.7247938, 'guidance_74': 0.72449344, 'guidance_41': 0.7236446, 'guidance_54': 0.72355306, 'guidance_40': 0.7183128, 'guidance_55': 0.7136133} -  Query: which government agencies work with law enforcement to address community concerns? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2522]: {'guidance_92': 0.74713075, 'guidance_38': 0.74560666, 'guidance_36': 0.7448852, 'guidance_75': 0.73604465, 'guidance_28': 0.7326049, 'guidance_13': 0.73128396, 'guidance_73': 0.72956616, 'guidance_55': 0.72895736, 'guidance_74': 0.7248207, 'guidance_39': 0.7233648} -  Query: why does community policing need decentralized decision making? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2523]: {'guidance_40': 0.66792303, 'guidance_93': 0.65269, 'guidance_55': 0.652882} -  Query: what is chp rehire -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2524]: {'guidance_78': 0.6894199, 'guidance_34': 0.6734118, 'guidance_59': 0.6759892, 'guidance_94': 0.67500114, 'guidance_58': 0.670767, 'guidance_17': 0.6736524, 'guidance_60': 0.6727413} -  Query: inmates must be assigned to restrictive housing -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2525]: {'guidance_58': 0.6055426, 'guidance_61': 0.59856206, 'guidance_69': 0.60619205, 'guidance_90': 0.59864074} -  Query: what is the role of an intern supervisor in training program -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2526]: {'guidance_36': 0.7574044, 'guidance_39': 0.755431, 'guidance_42': 0.7550154, 'guidance_76': 0.7550114, 'guidance_38': 0.7544232, 'guidance_92': 0.74941236, 'guidance_53': 0.7491067, 'guidance_14': 0.7490127, 'guidance_41': 0.74828935, 'guidance_29': 0.74823487} -  Query: how to report subrecipient executive compensation -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2527]: {'guidance_59': 0.64303136} -  Query: who reviews inmates at smu -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2528]: {'memos_34': 0.65538937, 'memos_60': 0.67142534, 'memos_30': 0.64494735} -  Query: can the president remove ftc commissioners -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2529]: {'guidance_92': 0.71530294, 'guidance_39': 0.70997626, 'guidance_38': 0.71224695, 'guidance_36': 0.7118246, 'guidance_55': 0.7101174, 'guidance_74': 0.7093786, 'guidance_29': 0.7085369, 'guidance_14': 0.7083665, 'guidance_40': 0.7064916} -  Query: what skills is needed for community policing -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2530]: {'guidance_93': 0.6860506, 'guidance_55': 0.6868955} -  Query: what is required for a cops grant -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2531]: {'guidance_19': 0.64618635, 'guidance_65': 0.6457247, 'guidance_78': 0.6556039, 'guidance_61': 0.65060306, 'guidance_44': 0.64401984} -  Query: types of juvenile facilities -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2532]: {'memos_9': 0.6641124, 'guidance_57': 0.6342368, 'memos_85': 0.6365987} -  Query: which u.s. congressman has the authority to require the states to lodge federal detainees for federal trial -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2533]: {'guidance_61': 0.62983614, 'guidance_62': 0.6134786, 'guidance_92': 0.6146309, 'guidance_91': 0.6108704} -  Query: what is the proposal evaluation process -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2534]: {'guidance_69': 0.6110295, 'legal-advice_28': 0.60679764, 'legal-advice_74': 0.60348797, 'guidance_92': 0.6016914, 'guidance_55': 0.6041154, 'guidance_91': 0.60391164, 'guidance_51': 0.60320824} -  Query: what is a necessary local official -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2535]: {'legal-advice_1': 0.6280893} -  Query: is a 1099 reportable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2536]: {'guidance_61': 0.6175104, 'guidance_45': 0.61814016} -  Query: what is the checklist for center discipline committee certification -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2537]: {'legal-advice_9': 0.6422277, 'legal-advice_1': 0.6300003, 'legal-advice_60': 0.63585913, 'guidance_69': 0.63439506, 'legal-advice_0': 0.6312716} -  Query: internal revenue service memo release release number -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2538]: {'guidance_91': 0.7394328, 'guidance_73': 0.73430026, 'guidance_53': 0.7363777} -  Query: where and when to report a tribal resource grant program (trgp) grant -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2539]: {'memos_97': 0.6250402, 'memos_87': 0.63726044, 'memos_90': 0.63301736, 'memos_49': 0.6292732, 'memos_94': 0.6276818, 'memos_99': 0.6275203, 'memos_1': 0.62546015} -  Query: why did congress specifically intend to override other statutes of limitations? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2540]: {'memos_98': 0.64748406, 'memos_42': 0.61892086, 'legal-advice_28': 0.6147035, 'memos_85': 0.6057219, 'memos_50': 0.60540384, 'legal-advice_74': 0.6049379} -  Query: indemnification of employee for personal liability arising from official action is -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2541]: {'legal-advice_40': 0.59485126} -  Query: how is the class of asset postf 134629-07 supported? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2542]: {'legal-advice_75': 0.61488044, 'legal-advice_18': 0.6178465} -  Query: can domestic subsidiaries offsetting positions be a straddle position? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2543]: {'guidance_69': 0.62385094, 'guidance_62': 0.59835964, 'legal-advice_0': 0.60920864, 'memos_0': 0.6066406, 'guidance_91': 0.60322356, 'memos_10': 0.6018401, 'memos_59': 0.5976112, 'guidance_38': 0.5951777, 'guidance_88': 0.5937339} -  Query: what is an organizational conflict of interest -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2544]: {'legal-advice_1': 0.6454343, 'legal-advice_61': 0.6468721} -  Query: is income excludable from taxable income -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2545]: {'legal-advice_9': 0.61863613, 'legal-advice_50': 0.6032651, 'legal-advice_1': 0.5969129, 'memos_87': 0.60053134, 'memos_10': 0.5972896, 'legal-advice_28': 0.5960014} -  Query: is section 197 ratable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2546]: {'memos_1': 0.6427735, 'memos_39': 0.6464921, 'memos_80': 0.6471829} -  Query: why can the attorney general not pursue lawsuits -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2547]: {'guidance_65': 0.63363487, 'guidance_17': 0.63750595, 'guidance_57': 0.6331036, 'guidance_46': 0.6332582} -  Query: reasons why an inmate may not be removed from the resolve coordinator's office -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2548]: {'guidance_65': 0.6555152, 'guidance_17': 0.6501015} -  Query: which inmate can be placed directly into the challenge program? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2549]: {'guidance_69': 0.64021933, 'guidance_5': 0.61724246, 'guidance_57': 0.60440093, 'guidance_88': 0.6071069, 'guidance_36': 0.60466903, 'guidance_1': 0.60331446, 'guidance_12': 0.6027685, 'guidance_64': 0.6019301, 'legal-advice_1': 0.60174346} -  Query: us dept of justice immigration fax number -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2550]: {'guidance_82': 0.6827897, 'guidance_68': 0.69132775} -  Query: how to review inmate central file -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2551]: {'guidance_80': 0.7239045, 'guidance_60': 0.6945818, 'guidance_99': 0.66187614, 'guidance_57': 0.6760551, 'guidance_45': 0.66715807, 'guidance_59': 0.6628228, 'guidance_61': 0.6604263} -  Query: standards for administration of correctional agencies -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2552]: {'guidance_93': 0.61, 'guidance_40': 0.6238672, 'guidance_55': 0.6081311, 'guidance_74': 0.59929246, 'guidance_60': 0.5969635, 'guidance_69': 0.5958958, 'guidance_92': 0.59350556} -  Query: what is the purpose of a mou agreement -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2553]: {'guidance_70': 0.6121362, 'guidance_78': 0.6407233, 'guidance_49': 0.61090046, 'guidance_17': 0.61887795} -  Query: which definition describes a person who has engaged in sexually violent conduct or attempted to engage in sexually violent conduct? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2554]: {'legal-advice_1': 0.6246258, 'legal-advice_0': 0.6258268} -  Query: what is the memorandum number for internal revenue service? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2555]: {'guidance_32': 0.6595742} -  Query: do inmate have commissary privilege -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2556]: {'guidance_55': 0.66865504, 'guidance_22': 0.6659209, 'guidance_25': 0.6645735, 'guidance_74': 0.6580597, 'guidance_92': 0.6575045, 'guidance_93': 0.6566801, 'guidance_91': 0.65558034, 'guidance_40': 0.6551567, 'guidance_24': 0.654726, 'guidance_38': 0.65422964} -  Query: why are cops funds used more efficiently -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2557]: {'guidance_91': 0.62760603, 'guidance_73': 0.6450481, 'guidance_92': 0.6196321, 'guidance_24': 0.61418873, 'guidance_53': 0.612504} -  Query: what does trgp pay for -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2558]: {'guidance_91': 0.72169083, 'guidance_92': 0.7086583, 'guidance_93': 0.708725, 'guidance_30': 0.71005666, 'guidance_54': 0.70923865, 'guidance_12': 0.7087971} -  Query: who is responsible for developing, approval, and operating of cops community policing development programs? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2559]: {'legal-advice_0': 0.6429189} -  Query: do tax practitioners need to retain client records -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2560]: {'guidance_81': 0.64460826, 'guidance_85': 0.63218045, 'guidance_39': 0.62538284, 'guidance_36': 0.62361753, 'guidance_38': 0.62314594, 'guidance_51': 0.6224828, 'guidance_73': 0.6216372, 'guidance_42': 0.62158054, 'guidance_41': 0.6181195} -  Query: what is the bureau of citizenship & immigration service employment eligibility verification form -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2561]: {'legal-advice_69': 0.63691187, 'legal-advice_60': 0.6209862, 'guidance_61': 0.61939895, 'guidance_74': 0.6182029} -  Query: when to report service closing agreement to the jc -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2562]: {'memos_35': 0.7636784, 'memos_72': 0.62112725, 'memos_39': 0.6230193, 'memos_41': 0.61651176, 'memos_58': 0.6254921, 'memos_57': 0.61465865} -  Query: what was the precedent for a presidential appearance as a character witness in a civil or criminal proceedings -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2563]: {'legal-advice_51': 0.58781415, 'legal-advice_40': 0.6001491, 'legal-advice_93': 0.594853, 'legal-advice_2': 0.59247774, 'guidance_62': 0.5924612} -  Query: who determines the profit per unit on a pool? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2564]: {'guidance_74': 0.652921, 'guidance_93': 0.65673506, 'guidance_14': 0.6565919, 'guidance_91': 0.65113, 'guidance_92': 0.65472734, 'guidance_22': 0.6531829, 'guidance_55': 0.65065664, 'guidance_36': 0.6494504} -  Query: what is the objective of an oig audit? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2565]: {'guidance_7': 0.6343125, 'guidance_6': 0.62775433, 'guidance_1': 0.6380148, 'guidance_2': 0.6301886} -  Query: what is the department of justice doing regarding the threat against election workers? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2566]: {'legal-advice_48': 0.691421} -  Query: when may a deduct amounts paid to a store to redeem gift checks? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2567]: {'memos_3': 0.76473576, 'memos_66': 0.72488683} -  Query: which branch has the power to make appointments during the recess period? -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2568]: {'guidance_93': 0.706108, 'guidance_38': 0.7189573, 'guidance_91': 0.7185411, 'guidance_40': 0.71319646, 'guidance_92': 0.7008877, 'guidance_39': 0.7003151, 'guidance_30': 0.698394, 'guidance_12': 0.69813573} -  Query: how to conduct a single audit under cops office regulations -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2569]: {'guidance_69': 0.5976246, 'guidance_93': 0.57700497, 'guidance_60': 0.579826, 'guidance_29': 0.5790745, 'memos_21': 0.5775261, 'guidance_32': 0.57681084, 'guidance_22': 0.57594174} -  Query: what does operations lieutenant do -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2570]: {'guidance_91': 0.74936706, 'guidance_73': 0.73809105, 'guidance_24': 0.73881453, 'guidance_53': 0.73755884} -  Query: what is the cops tribal resource grant -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2571]: {'legal-advice_45': 0.64038765, 'legal-advice_79': 0.6406283, 'legal-advice_16': 0.64115435, 'legal-advice_43': 0.6391488} -  Query: is corporation x amortizable -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2572]: {'guidance_21': 0.64014035, 'guidance_93': 0.64188063, 'guidance_89': 0.62053794, 'guidance_39': 0.629508, 'guidance_64': 0.62510103, 'guidance_55': 0.6233866, 'guidance_38': 0.6227219, 'memos_97': 0.6227216} -  Query: which amendments to the education act prohibit discrimination -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2573]: {'legal-advice_79': 0.6237573, 'legal-advice_43': 0.6297902, 'legal-advice_5': 0.6299217, 'legal-advice_16': 0.62617} -  Query: are transaction costs capitalized -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2574]: {'legal-advice_56': 0.61362827, 'guidance_91': 0.5913753, 'memos_18': 0.6111997, 'memos_0': 0.60470855, 'memos_87': 0.5990728, 'guidance_92': 0.5981452, 'guidance_27': 0.5978875, 'memos_69': 0.5972979, 'memos_6': 0.5914125} -  Query: why was the bcbsa exemption proposed by gao and bcbsa -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2575]: {'legal-advice_64': 0.65445435, 'guidance_69': 0.6003596, 'legal-advice_77': 0.58719, 'legal-advice_36': 0.5796609, 'legal-advice_29': 0.57208437} -  Query: what is useful life of a baseball contract -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2576]: {'guidance_39': 0.6769481, 'guidance_91': 0.6657251, 'guidance_14': 0.66151094, 'guidance_12': 0.66132545, 'guidance_75': 0.65855175, 'guidance_22': 0.6565428, 'guidance_92': 0.65523154, 'guidance_28': 0.65239185, 'guidance_40': 0.65139633, 'guidance_25': 0.65139186} -  Query: when is reprisal against an official prohibited -
# [SearchClient][ranx-index-voyage-law-2] run_dict[2577]: {'memos_46': 0.5958881, 'memos_81': 0.59482515, 'memos_5': 0.5989815, 'memos_97': 0.5944963} -  Query: when did the ratification of the havana convention happen -

# %%
# Out:
# 3

# %%
with open(f"results/result_k.json", "w") as file:
    json.dump(results_dfs, file, indent=2)

# %%
from ranx import Qrels, Run

# Create qrels from labels after converting dtypes
qrels = Qrels.from_df(filtered_labels_df, q_id_col="query_id", doc_id_col="doc_id", score_col="score")

compare_dfs = {}
k_list = [3,5, 10]
for k in k_list: 
    # create runs for ranx
    ada2_run = Run(results_dfs[k]["ada2"] , name=f"ada2_content")
    t3small_run = Run(results_dfs[k]["t3small"] , name=f"t3small_content")
    voyage_law2_run = Run(results_dfs[k]["voyage_law2"] , name=f"voyage_law2_content")
    compare_dfs[k] = compare_runs(qrels, 
                                ada2_run, 
                                t3small_run, 
                                voyage_law2_run, 
                                result_folder=folder, k=k)

# %%
compare_dfs[3]
# Out:
#            model_names  precision@3  recall@3     mrr@3     dcg@3    ndcg@3
# 0         ada2_content     0.208042  0.613394  0.528769  5.548893  0.549249
# 1      t3small_content     0.181277  0.537704  0.463926  4.853129  0.481812
# 2  voyage_law2_content     0.176881  0.523850  0.430631  4.570788  0.453663

# %% [markdown]
# # 5. Comparison

# %%
results_df = pd.read_csv(f"results/{folder}/comparison_results_k3.csv")
results_df
# Out:
#            model_names  precision@3  recall@3     mrr@3     dcg@3    ndcg@3
# 0         ada2_content     0.208042  0.613394  0.528769  5.548893  0.549249
# 1      t3small_content     0.181277  0.537704  0.463926  4.853129  0.481812
# 2  voyage_law2_content     0.176881  0.523850  0.430631  4.570788  0.453663

# %%
results_df = pd.read_csv(f"results/{folder}/comparison_results_k5.csv")
results_df
# Out:
#            model_names  precision@5  recall@5     mrr@5     dcg@5    ndcg@5
# 0         ada2_content     0.142126  0.694844  0.526998  5.750876  0.567523
# 1      t3small_content     0.122576  0.603562  0.454157  4.951668  0.490773
# 2  voyage_law2_content     0.121334  0.595656  0.426881  4.733417  0.468361

# %%
results_df = pd.read_csv(f"results/{folder}/comparison_results_k10.csv")
results_df
# Out:
#            model_names  precision@10  recall@10    mrr@10    dcg@10   ndcg@10
# 0         ada2_content      0.081963   0.794785  0.478041  5.632844  0.552788
# 1      t3small_content      0.072033   0.702986  0.432084  5.032378  0.496447
# 2  voyage_law2_content      0.072033   0.700126  0.397977  4.779659  0.470095
