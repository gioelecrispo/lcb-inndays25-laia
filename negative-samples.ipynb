# %% [markdown]
# # Processing dataset

# %%
from glob import glob

def list_all_files(directory):
    all_paths = glob(directory + '/**/*', recursive=True)
    all_files = [f.replace("\\", "/") for f in all_paths if os.path.isfile(f)]
    return all_files

# %%
import json
import os
import random 

def load_all_chunks(base_folder):
    filenames = list_all_files(base_folder)
    
    chunks = {}
    for filename in filenames:
        with open(filename, "r", encoding="utf-8") as file:
            chunks_document = json.load(file)
            for chunk in chunks_document["chunks"]:
                chunk["doc_id"] = chunks_document["doc_id"]
                chunks[chunk["id"]] = chunk
    return chunks


def random_select_chunks(chunks_with_queries, num_samples=5, exclude_doc_id=None):
    exclude_ids = set()
    if exclude_doc_id is not None:
        exclude_ids = set([cid for cid in chunks_with_queries.keys() if cid.startswith(exclude_doc_id)])
    
    selected_chunks = []
    available_ids = list(set(chunks_with_queries.keys()) - exclude_ids)
    
    if len(available_ids) < num_samples:
        raise ValueError("Not enough unique chunks available to select the requested number of samples.")
    
    selected_ids = random.sample(available_ids, num_samples)
    
    for chunk_id in selected_ids:
        selected_chunks.append(chunks_with_queries[chunk_id])
    
    return selected_chunks


def compute_query_content_matches(chunks_with_queries, num_samples=5):
    query_content_lists = []
    for _, chunk_data in chunks_with_queries.items():
        if "queries" in chunk_data:
            queries = chunk_data["queries"]
            for query in queries:
                
                random_chunks = random_select_chunks(chunks_with_queries, num_samples=num_samples, exclude_doc_id=None)
                query_content_list = [{"text": c["content"], "querygen": query, "id": c["id"]} for c in random_chunks]
                query_content_lists.append(query_content_list)
    return query_content_lists

# %%
import pandas as pd
from pyterrier_doc2query import QueryScorer
from pyterrier_dr import ElectraScorer

query_scorer = QueryScorer(ElectraScorer())
base_folder = "resources/data/queries"

# all chunks are loaded from files with queries and their score => a map {"chunk_id": chunk_data} is built
chunks_with_queries = load_all_chunks(base_folder) 
# for each query, num_samples chunks are randomly taken (with their content and id) 
query_content_lists = compute_query_content_matches(chunks_with_queries, num_samples=5) 


for i, query_content_list in enumerate(query_content_lists):

    scores = query_scorer.transform(pd.DataFrame.from_records(query_content_list)).to_dict(orient='records')
    for score in scores:
        # update the map adding the new queries and their scores
        chunks_with_queries[score["id"]]["queries"].append(score["querygen"])
        chunks_with_queries[score["id"]]["queries_score"].append(float(score["querygen_score"][0]))
        
    print(f"Processing {i+1}/{len(query_content_lists)} query...")
    
# at the end we will have a map of all the chunks with some queries each that could have a positive value or negative values
# the value <= threshold=1.5 is considered Irrelevant, otherwise Relevant

# %%
import os 
output_folder = "resources/data/negqueries"

def save_data_with_queries(chunks_with_queries, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    doc_ids = list(set([c["doc_id"] for c in chunks_with_queries.values()]))

    for doc_id in doc_ids:
        chunks = [c for c in chunks_with_queries.values() if c["doc_id"] == doc_id]
        category = doc_id.split("_")[0] 
        chunks_data = []
        for chunk in chunks:
            chunk_data = {
                "id": chunk["id"],
                "chunk_id": chunk["chunk_id"],
                "content": chunk["content"],
                "queries": chunk["queries"],
                "queries_score": chunk["queries_score"]
            }
            chunks_data.append(chunk_data)
        chunks_document = {
            "doc_id": doc_id,
            "category": category,
            "chunks": chunks_data
        }

        outfile_name = f"{output_folder}/{category}/{doc_id}_negqueries.json"
        with open(outfile_name, "w", encoding="utf-8") as file:
            json.dump(chunks_document, file, indent=2)
            print(f"Saved {outfile_name} with {len(chunks_document['chunks'])} chunks.")
            
            
pd.DataFrame.from_dict(chunks_with_queries, orient='index').to_csv(f"{output_folder}/chunks_with_queries123.csv", index=False)
save_data_with_queries(chunks_with_queries, output_folder)
# Out:
# Saved resources/data/negqueries/legal-advice/legal-advice_72_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/eurlex/eurlex
negqueries.json with 5 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_79_negqueries.json with 43 chunks.
# Saved resources/data/negqueries/memos/memos_77_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_81_negqueries.json with 9 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_39_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_38_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/memos/memos_13_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_6_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_55_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/guidance/guidance_88_negqueries.json with 68 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_90_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/memos/memos_92_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/memos/memos_33_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/guidance/guidance_82_negqueries.json with 12 chunks.
# Saved resources/data/negqueries/memos/memos_93_negqueries.json with 14 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_32_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_76_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_17_negqueries.json with 8 chunks.
# Saved resources/data/negqueries/memos/memos_30_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/memos/memos_99_negqueries.json with 13 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_41_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/memos/memos_63_negqueries.json with 6 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_56_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_58_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/memos/memos_12_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/memos/memos_81_negqueries.json with 34 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_89_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_30_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_3_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_8_negqueries.json with 9 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_40_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_81_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/memos/memos_9_negqueries.json with 8 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_43_negqueries.json with 35 chunks.
# Saved resources/data/negqueries/guidance/guidance_97_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/guidance/guidance_14_negqueries.json with 122 chunks.
# Saved resources/data/negqueries/guidance/guidance_36_negqueries.json with 107 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_84_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_80_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/guidance/guidance_13_negqueries.json with 75 chunks.
# Saved resources/data/negqueries/memos/memos_31_negqueries.json with 6 chunks.
# Saved resources/data/negqueries/guidance/guidance_16_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/memos/memos_41_negqueries.json with 12 chunks.
# Saved resources/data/negqueries/memos/memos_69_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/memos/memos_72_negqueries.json with 17 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_0_negqueries.json with 61 chunks.
# Saved resources/data/negqueries/guidance/guidance_42_negqueries.json with 78 chunks.
# Saved resources/data/negqueries/guidance/guidance_48_negqueries.json with 6 chunks.
# Saved resources/data/negqueries/guidance/guidance_53_negqueries.json with 108 chunks.
# Saved resources/data/negqueries/guidance/guidance_89_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/memos/memos_58_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/memos/memos_1_negqueries.json with 37 chunks.
# Saved resources/data/negqueries/guidance/guidance_10_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/memos/memos_86_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_95_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/memos/memos_91_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/memos/memos_3_negqueries.json with 3 chunks.
# Saved resources/data/negqueries/guidance/guidance_20_negqueries.json with 15 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_52_negqueries.json with 12 chunks.
# Saved resources/data/negqueries/memos/memos_28_negqueries.json with 23 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_13_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_80_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_15_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/memos/memos_52_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_84_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_45_negqueries.json with 87 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_87_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_82_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_79_negqueries.json with 57 chunks.
# Saved resources/data/negqueries/memos/memos_39_negqueries.json with 10 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_54_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_64_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/memos/memos_97_negqueries.json with 34 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_21_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_37_negqueries.json with 9 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_96_negqueries.json with 11 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_61_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_27_negqueries.json with 15 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_65_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_55_negqueries.json with 83 chunks.
# Saved resources/data/negqueries/guidance/guidance_29_negqueries.json with 121 chunks.
# Saved resources/data/negqueries/memos/memos_18_negqueries.json with 11 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_80_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/guidance/guidance_84_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/guidance/guidance_39_negqueries.json with 109 chunks.
# Saved resources/data/negqueries/memos/memos_42_negqueries.json with 9 chunks.
# Saved resources/data/negqueries/guidance/guidance_98_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/guidance/guidance_58_negqueries.json with 33 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_20_negqueries.json with 6 chunks.
# Saved resources/data/negqueries/guidance/guidance_91_negqueries.json with 109 chunks.
# Saved resources/data/negqueries/guidance/guidance_76_negqueries.json with 84 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_44_negqueries.json with 5 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_9_negqueries.json with 11 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_60_negqueries.json with 7 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_60_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/guidance/guidance_47_negqueries.json with 30 chunks.
# Saved resources/data/negqueries/legal-advice/legal-advice_34_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/memos/memos_14_negqueries.json with 8 chunks.
# Saved resources/data/negqueries/guidance/guidance_52_negqueries.json with 15 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_31_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_96_negqueries.json with 1 chunks.
# Saved resources/data/negqueries/guidance/guidance_32_negqueries.json with 105 chunks.
# Saved resources/data/negqueries/guidance/guidance_62_negqueries.json with 24 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_36_negqueries.json with 11 chunks.
# Saved resources/data/negqueries/eurlex/eurlex_3_negqueries.json with 2 chunks.
# Saved resources/data/negqueries/memos/memos_36_negqueries.json with 4 chunks.
# Saved resources/data/negqueries/guidance/guidance_44_negqueries.json with 7 chunks.
